# %% [markdown]
# <a href="https://colab.research.google.com/github/parkyanghu/Machine-Learning1901266/blob/main/%EB%B0%95%EC%96%91%ED%9B%84_7%EA%B0%958%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
titinic=sns.load_dataset("titanic")
titinic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import numpy as np

# %%
x=np.ramdom.rand(100)
eps=np.random.rand(100)/1.5
y=3*x+1+eps

plt.plot(x,y,'.')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-de77e36a1d78> in <module>
# ----> 1 x=np.ramdom.rand(100)
#       2 eps=np.random.rand(100)/1.5
#       3 y=3*x+1+eps
#       4
#       5 plt.plot(x,y,'.')
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'ramdom'

# %%
a=0
b=0
alpha=0.01
n=100
err_evolve=[]
it_index=[]
for it in range(2000):
  delta_a=0
  delta_b=0
  
  err=0
  for i in range(n):
   delta_a=delta_a+2*(a*x[i]+b-y[i])*x[i]
   delta_a=delta_b+2*a(*x[i]+b-y[i])
   err=err+(a*x[i]+b-y[i])*(a*x[i]+b-y[i])/n
  a=a-alpha*delta_a/n
  b=a+alpha*delta_b/n
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-bf209e744d3f> in <module>
#      11   err=0
#      12   for i in range(n):
# ---> 13    delta_a=delta_a+2*(a*x[i]+b-y[i])*x[i]
#      14    delta_a=delta_b+2*a(*x[i]+b-y[i])
#      15    err=err+(a*x[i]+b-y[i])*(a*x[i]+b-y[i])/n
#
# TypeError: 'int' object is not subscriptable
